# %%
import json
import re
from collections import defaultdict, Counter
import pandas as pd

# %%
# Load the original JSON data
with open('gg2013.json', 'r') as file:
    tweets = json.load(file)#[:170000]

# Function to identify award patterns dynamically
def find_award_patterns(tweets):
    award_patterns = []
    for tweet in tweets:
        text = tweet['text'].lower()
        matches = re.findall(r'best [\w\s\-]+', text)
        for match in matches:
            award_patterns.append(match.strip())
    return award_patterns

# Find award patterns dynamically from the tweets
award_patterns = find_award_patterns(tweets)

# Count the frequency of each award pattern
award_counter = Counter(award_patterns)

# %%
# Get the top 25 most frequent awards
top_50_awards = award_counter.most_common(200)

# %%
top_25_awards_dict = {award: count for award, count in top_50_awards}

# %%
df= pd.DataFrame([top_25_awards_dict.keys(), top_25_awards_dict.values()]).T
df.columns= ['award', 'values']

# %%
df.head()
# Out:
#                             award values
# 0             best motion picture    423
# 1              best original song    401
# 2                   best director    379
# 3                      best actor    346
# 4  best actor in a motion picture    280

# %%
awards=df['award'].values

# %%
awards
# Out:
# array(['best motion picture', 'best original song', 'best director',
#        'best actor', 'best actor in a motion picture', 'best picture',
#        'best supporting actress in a motion picture - anne hathaway - les miserables -',
#        'best original song -', 'best supporting actress',
#        'best screenplay', 'best actress',
#        'best actress in a motion picture',
#        'best motion picture - comedy or musical - les miserables -',
#        'best supporting actress in a motion picture',
#        'best director - ben affleck',
#        'best actor in a motion picture - comedy or musical - hugh jackman',
#        'best tv series',
#        'best actress in a motion picture - comedy or musical - jennifer lawrence - silver linings playbook -',
#        'best supporting actor', 'best dressed',
#        'best supporting actor in a motion picture - christoph waltz - django unchained -',
#        'best motion picture - drama - argo -',
#        'best supporting actress in a tv movie', 'best speech ever',
#        'best television series - drama - homeland',
#        'best screenplay - quentin tarantino - django unchained -',
#        'best acceptance speech ever', 'best actress in a comedy series',
#        'best actor in a motion picture - drama - daniel day lewis - lincoln -',
#        'best buy to demonstrate picture quality',
#        'best animated feature film - brave', 'best drama',
#        'best animated film', 'best comedy series',
#        'best original score - mychael danna - life of pi -',
#        'best original song for',
#        'best actress in a motion picture - drama - jessica chastain - zero dark thirty -',
#        'best original score', 'best motion picture drama goes to',
#        'best actor in a tv series', 'best song at the',
#        'best director for',
#        'best actress in a tv movie or miniseries - julianne moore - game change -',
#        'best television series actor - drama - damian lewis',
#        'best foreign film - amour', 'best comedy', 'best actress award',
#        'best actress in a tv series',
#        'best actor in a tv movie or miniseries - kevin costner - hatfields',
#        'best show on tv by miles', 'best foreign film',
#        'best animated feature film',
#        'best miniseries or motion picture made for television - game change -',
#        'best television series - comedy or musical - girls',
#        'best supporting actress in a motion picture is awarded to anne hathaway for',
#        'best actor in a television series - comedy or musical - don cheadle',
#        'best actress in a television series - drama - claire danes - homeland',
#        'best song', 'best motion picture - drama',
#        'best golden globes opening ever', 'best motion picture drama',
#        'best actress in a tv comedy',
#        'best supporting actor in a television series - ed harris - game change -',
#        'best director motion picture', 'best tv drama',
#        'best tv series actress - comedy or musical - lena dunham',
#        'best movie', 'best dressed at the', 'best actor for',
#        'best supporting actress for', 'best screenplay for',
#        'best original song for skyfall', 'best hosts ever',
#        'best director award for', 'best of the',
#        'best actress in a motion picture drama is jessica chastain for',
#        'best animated feature film is awarded to',
#        'best director for argo', 'best director category',
#        'best exotic marigold hotel',
#        'best supporting actress in a motion picture for', 'best friend',
#        'best moment of the', 'best foreign language film',
#        'best nominee cutaway of the night',
#        'best picture nominee lincoln', 'best animated feature',
#        'best movie comedy or musical', 'best drama at the',
#        'best animated feature at the',
#        'best actress in a miniseries or tv movie',
#        'best original song win at the',
#        'best actress in a tv comedy or musical goes to lena dunham for',
#        'best comedy series at the', 'best part of the',
#        'best supporting actress in a motion picture - anne hathaway - les miserables',
#        'best golden globes ever',
#        'best supporting actress in a tv series',
#        'best actor in a miniseries or tv movie',
#        'best supporting actor in', 'best supporting actor in a drama',
#        'best uhhhh', 'best actress in a comedy',
#        'best hosts to ever grace an awards show stage',
#        'best line of the', 'best supporting actress tv series',
#        'best director at the golden globes',
#        'best original song in a motion picture',
#        'best actor in a miniseries', 'best film of the year',
#        'best actor at', 'best ever', 'best supporting actor at',
#        'best screenplay for django unchained', 'best actress in tv drama',
#        'best comedy or musical',
#        'best motion picture - comedy or musical - les miserables',
#        'best movie actor', 'best line of the night',
#        'best supporting actress in a motion picture win for les miserables',
#        'best actress here',
#        'best performance by an actor in a motion picture - drama',
#        'best supporting actor globe for', 'best moments - usa today http',
#        'best actress at the', 'best supporting actress in',
#        'best supporting actress for les miserables',
#        'best director - argo', 'best dressed list',
#        'best original song at the', 'best supporting actress http',
#        'best actress in a drama', 'best joke of the night',
#        'best supporting actor for django unchained',
#        'best tv series - drama', 'best film',
#        'best string of yesterdays i have ever had',
#        'best tv series - comedy or a musical winner is',
#        'best movie actress', 'best film in the comedy',
#        'best supporting actor in a motion picture',
#        'best tv movie or miniseries',
#        'best original score - motion picture is awarded to mychael danna for the',
#        'best original song - motion picture',
#        'best screenplay - motion picture', 'best actress for',
#        'best song at golden globes', 'best score',
#        'best original song at the golden globes and',
#        'best things that have ever happened',
#        'best known for playing jacob in water for elephants',
#        'best director at the', 'best comedy actor in a television series',
#        'best tv comedy', 'best movie - comedy or musical',
#        'best actor in a drama wa', 'best dressed of the night',
#        'best friends', 'best actress in a mini-series',
#        'best part of the golden globes', 'best show on tv',
#        'best actress in a tv series comedy or musical at the',
#        'best actor in a comedy or musical', 'best musical',
#        'best insults at the 2013 golden globes', 'best tv movie',
#        'best tv series drama', 'best drama series',
#        'best original song goes to', 'best winner',
#        'best actress in a comedy or musical',
#        'best screenplay goes to quentin tarantino for django unchained',
#        'best motion picture screenplay for',
#        'best screenplay - django unchained',
#        'best actor tv series - comedy or musical goes to don cheadle for',
#        'best film director for', 'best picture at the',
#        'best motion picture drama goes to argo', 'best part of',
#        'best mini-series or tv movie', 'best television series',
#        'best original score - motion picture', 'best speech so far',
#        'best of all', 'best sense of humor',
#        'best actress in a comedy or musical for',
#        'best supporting actress for les mis',
#        'best string of yesterdays i', 'best actress in a tv drama',
#        'best actor in a comedy or musical tv series for',
#        'best actress drama winner at golden globes 2013',
#        'best supporting actor for', 'best supporting actor at the',
#        'best speech of the night', 'best extreme closeups at the',
#        'best tv drama series', 'best song for skyfall',
#        'best original song for motion picture http',
#        'best original screenplay', 'best actor for les mis'], dtype=object)

# %%
import re

def clean_awards(awards):
    transformed_awards = set()
    
    for award in awards:
        # Normalize text by converting to lowercase and removing leading/trailing whitespace
        clean_award = award.lower().strip()
        
        # Remove extra details like names, movie titles, URLs, etc.
        clean_award = re.sub(r' - .*', '', clean_award)  # Remove everything after the first " - "
        clean_award = re.sub(r'http\S+', '', clean_award)  # Remove URLs
        clean_award = re.sub(r'\b(for|goes to|awarded to|win at|at the)\b.*', '', clean_award)  # Remove specific trailing phrases
        clean_award = re.sub(r'\bbest performance by an .*', '', clean_award)  # Remove detailed performer descriptions
        
        # Standardize phrases
        clean_award = re.sub(r'\b(tv series|television series)\b', 'television series', clean_award)
        clean_award = re.sub(r'\bmini-series\b', 'mini-series or motion picture made for television', clean_award)
        clean_award = re.sub(r'\bmovie\b', 'motion picture', clean_award)
        
        # Add the cleaned award to the set to ensure uniqueness
        transformed_awards.add(clean_award.strip())
    
    # Sort the set and return it as a list
    return sorted(transformed_awards)

# %%
res= clean_awards(awards)

# %%
res
# Out:
# ['',
#  'best acceptance speech ever',
#  'best actor',
#  'best actor at',
#  'best actor in a comedy or musical',
#  'best actor in a comedy or musical television series',
#  'best actor in a drama wa',
#  'best actor in a miniseries',
#  'best actor in a miniseries or tv motion picture',
#  'best actor in a motion picture',
#  'best actor in a television series',
#  'best actor in a tv motion picture or miniseries',
#  'best actor television series',
#  'best actress',
#  'best actress award',
#  'best actress drama winner at golden globes 2013',
#  'best actress here',
#  'best actress in a comedy',
#  'best actress in a comedy or musical',
#  'best actress in a comedy series',
#  'best actress in a drama',
#  'best actress in a mini-series or motion picture made for television',
#  'best actress in a miniseries or tv motion picture',
#  'best actress in a motion picture',
#  'best actress in a motion picture drama is jessica chastain',
#  'best actress in a television series',
#  'best actress in a television series comedy or musical',
#  'best actress in a tv comedy',
#  'best actress in a tv comedy or musical',
#  'best actress in a tv drama',
#  'best actress in a tv motion picture or miniseries',
#  'best actress in tv drama',
#  'best animated feature',
#  'best animated feature film',
#  'best animated feature film is',
#  'best animated film',
#  'best buy to demonstrate picture quality',
#  'best comedy',
#  'best comedy actor in a television series',
#  'best comedy or musical',
#  'best comedy series',
#  'best director',
#  'best director award',
#  'best director category',
#  'best director motion picture',
#  'best drama',
#  'best drama series',
#  'best dressed',
#  'best dressed list',
#  'best dressed of the night',
#  'best ever',
#  'best exotic marigold hotel',
#  'best extreme closeups',
#  'best film',
#  'best film director',
#  'best film in the comedy',
#  'best film of the year',
#  'best foreign film',
#  'best foreign language film',
#  'best friend',
#  'best friends',
#  'best golden globes ever',
#  'best golden globes opening ever',
#  'best hosts ever',
#  'best hosts to ever grace an awards show stage',
#  'best insults',
#  'best joke of the night',
#  'best known',
#  'best line of the',
#  'best line of the night',
#  'best mini-series or motion picture made for television or tv motion picture',
#  'best miniseries or motion picture made',
#  'best moment of the',
#  'best moments',
#  'best motion picture',
#  'best motion picture actor',
#  'best motion picture actress',
#  'best motion picture comedy or musical',
#  'best motion picture drama',
#  'best motion picture screenplay',
#  'best musical',
#  'best nominee cutaway of the night',
#  'best of all',
#  'best of the',
#  'best original score',
#  'best original screenplay',
#  'best original song',
#  'best original song -',
#  'best original song in a motion picture',
#  'best part of',
#  'best part of the',
#  'best part of the golden globes',
#  'best picture',
#  'best picture nominee lincoln',
#  'best score',
#  'best screenplay',
#  'best sense of humor',
#  'best show on tv',
#  'best show on tv by miles',
#  'best song',
#  'best song at golden globes',
#  'best speech ever',
#  'best speech of the night',
#  'best speech so far',
#  'best string of yesterdays i',
#  'best string of yesterdays i have ever had',
#  'best supporting actor',
#  'best supporting actor at',
#  'best supporting actor globe',
#  'best supporting actor in',
#  'best supporting actor in a drama',
#  'best supporting actor in a motion picture',
#  'best supporting actor in a television series',
#  'best supporting actress',
#  'best supporting actress http',
#  'best supporting actress in',
#  'best supporting actress in a motion picture',
#  'best supporting actress in a motion picture is',
#  'best supporting actress in a motion picture win',
#  'best supporting actress in a television series',
#  'best supporting actress in a tv motion picture',
#  'best supporting actress television series',
#  'best television series',
#  'best television series actor',
#  'best television series actress',
#  'best television series drama',
#  'best things that have ever happened',
#  'best tv comedy',
#  'best tv drama',
#  'best tv drama series',
#  'best tv motion picture',
#  'best tv motion picture or miniseries',
#  'best uhhhh',
#  'best winner']
